# %% [markdown]
# ## Collaborative Filtering with Cold Start
# ### Model inspried by: Ibtesam Ahmed
# #### Link: https://www.kaggle.com/code/ibtesama/getting-started-with-a-movie-recommendation-system/notebook
#
#
# ##### Using SVD learning model and including user cold start scenario
# ##### Change cold start user to 2
# ##### n_factor = 20, n_epochs = 30, lr_all = .005, reg_all = .1

# %%
import pandas as pd
from surprise import Reader, Dataset, SVD, accuracy

# %%
# Load dataset
ratings = pd.read_csv('../tmdb/ratings_small.csv')
reader = Reader(rating_scale=(0.5, 5.0))

# %%
# Choose a user to simulate cold start
user_id = 2
user_ratings = ratings[ratings['userId'] == user_id]

# Keep only 5 ratings for the user, remove the rest
keep_ratings = user_ratings.sample(n=5, random_state=42)   # the 5 ratings we keep
remove_ratings = user_ratings.drop(keep_ratings.index)      # the rest we remove

# Remove the other ratings from the dataset for training
train_ratings = ratings.drop(remove_ratings.index)

# %%
# Number of movies user rated
print(len(user_ratings))
# Out:
# 76

# %%
# cold start information
keep_ratings
# Out:
#     userId  movieId  rating  timestamp
# 24       2       50     4.0  835355586
# 55       2      349     4.0  835355441
# 30       2      153     4.0  835355441
# 20       2       10     4.0  835355493
# 65       2      382     3.0  835356165

# %%
# Load the training set into Surprise
train_data = Dataset.load_from_df(train_ratings[['userId','movieId','rating']], reader)
trainset = train_data.build_full_trainset()

# %%
# Train the SVD model
svd = SVD(n_factors=20, n_epochs=30, lr_all=0.005, reg_all=0.1)
svd.fit(trainset)

# %%
# Predict the removed ratings for the user
predictions = []
for movie_id in remove_ratings['movieId']:
    true_rating = ratings[(ratings['userId'] == user_id) & (ratings['movieId'] == movie_id)]['rating'].values[0]
    pred = svd.predict(user_id, movie_id, r_ui=true_rating)
    predictions.append(pred)
    print(pred)
# Out:
# user: 2          item: 17         r_ui = 5.00   est = 4.02   {'was_impossible': False}
# user: 2          item: 39         r_ui = 5.00   est = 3.73   {'was_impossible': False}
# user: 2          item: 47         r_ui = 4.00   est = 4.10   {'was_impossible': False}
# user: 2          item: 52         r_ui = 3.00   est = 3.73   {'was_impossible': False}
# user: 2          item: 62         r_ui = 3.00   est = 3.81   {'was_impossible': False}
# user: 2          item: 110        r_ui = 4.00   est = 4.03   {'was_impossible': False}
# user: 2          item: 144        r_ui = 3.00   est = 3.54   {'was_impossible': False}
# user: 2          item: 150        r_ui = 5.00   est = 3.95   {'was_impossible': False}
# user: 2          item: 161        r_ui = 3.00   est = 3.93   {'was_impossible': False}
# user: 2          item: 165        r_ui = 3.00   est = 3.63   {'was_impossible': False}
# user: 2          item: 168        r_ui = 3.00   est = 3.36   {'was_impossible': False}
# user: 2          item: 185        r_ui = 3.00   est = 3.32   {'was_impossible': False}
# user: 2          item: 186        r_ui = 3.00   est = 3.03   {'was_impossible': False}
# user: 2          item: 208        r_ui = 3.00   est = 3.02   {'was_impossible': False}
# user: 2          item: 222        r_ui = 5.00   est = 3.94   {'was_impossible': False}
# user: 2          item: 223        r_ui = 1.00   est = 4.09   {'was_impossible': False}
# user: 2          item: 225        r_ui = 3.00   est = 3.31   {'was_impossible': False}
# user: 2          item: 235        r_ui = 3.00   est = 4.01   {'was_impossible': False}
# user: 2          item: 248        r_ui = 3.00   est = 3.22   {'was_impossible': False}
# user: 2          item: 253        r_ui = 4.00   est = 3.59   {'was_impossible': False}
# user: 2          item: 261        r_ui = 4.00   est = 3.84   {'was_impossible': False}
# user: 2          item: 265        r_ui = 5.00   est = 3.94   {'was_impossible': False}
# user: 2          item: 266        r_ui = 5.00   est = 3.59   {'was_impossible': False}
# user: 2          item: 272        r_ui = 3.00   est = 4.18   {'was_impossible': False}
# user: 2          item: 273        r_ui = 4.00   est = 3.22   {'was_impossible': False}
# user: 2          item: 292        r_ui = 3.00   est = 3.52   {'was_impossible': False}
# user: 2          item: 296        r_ui = 4.00   est = 4.33   {'was_impossible': False}
# user: 2          item: 300        r_ui = 3.00   est = 3.89   {'was_impossible': False}
# user: 2          item: 314        r_ui = 4.00   est = 3.89   {'was_impossible': False}
# user: 2          item: 317        r_ui = 2.00   est = 3.21   {'was_impossible': False}
# user: 2          item: 319        r_ui = 1.00   est = 4.09   {'was_impossible': False}
# user: 2          item: 339        r_ui = 3.00   est = 3.60   {'was_impossible': False}
# user: 2          item: 350        r_ui = 4.00   est = 3.50   {'was_impossible': False}
# user: 2          item: 356        r_ui = 3.00   est = 4.13   {'was_impossible': False}
# user: 2          item: 357        r_ui = 3.00   est = 3.79   {'was_impossible': False}
# user: 2          item: 364        r_ui = 3.00   est = 3.88   {'was_impossible': False}
# user: 2          item: 367        r_ui = 3.00   est = 3.30   {'was_impossible': False}
# user: 2          item: 370        r_ui = 2.00   est = 3.30   {'was_impossible': False}
# user: 2          item: 371        r_ui = 3.00   est = 3.56   {'was_impossible': False}
# user: 2          item: 372        r_ui = 3.00   est = 3.36   {'was_impossible': False}
# user: 2          item: 377        r_ui = 3.00   est = 3.70   {'was_impossible': False}
# user: 2          item: 405        r_ui = 2.00   est = 2.74   {'was_impossible': False}
# user: 2          item: 410        r_ui = 3.00   est = 3.31   {'was_impossible': False}
# user: 2          item: 454        r_ui = 4.00   est = 3.63   {'was_impossible': False}
# user: 2          item: 457        r_ui = 3.00   est = 4.07   {'was_impossible': False}
# user: 2          item: 468        r_ui = 4.00   est = 3.51   {'was_impossible': False}
# user: 2          item: 474        r_ui = 2.00   est = 3.99   {'was_impossible': False}
# user: 2          item: 480        r_ui = 4.00   est = 3.82   {'was_impossible': False}
# user: 2          item: 485        r_ui = 3.00   est = 3.21   {'was_impossible': False}
# user: 2          item: 497        r_ui = 3.00   est = 4.16   {'was_impossible': False}
# user: 2          item: 500        r_ui = 4.00   est = 3.67   {'was_impossible': False}
# user: 2          item: 508        r_ui = 4.00   est = 3.84   {'was_impossible': False}
# user: 2          item: 509        r_ui = 4.00   est = 3.92   {'was_impossible': False}
# user: 2          item: 515        r_ui = 4.00   est = 4.26   {'was_impossible': False}
# user: 2          item: 527        r_ui = 4.00   est = 4.33   {'was_impossible': False}
# user: 2          item: 537        r_ui = 4.00   est = 3.34   {'was_impossible': False}
# user: 2          item: 539        r_ui = 3.00   est = 3.62   {'was_impossible': False}
# user: 2          item: 550        r_ui = 3.00   est = 3.48   {'was_impossible': False}
# user: 2          item: 551        r_ui = 5.00   est = 3.88   {'was_impossible': False}
# user: 2          item: 552        r_ui = 3.00   est = 3.38   {'was_impossible': False}
# user: 2          item: 585        r_ui = 5.00   est = 3.28   {'was_impossible': False}
# user: 2          item: 586        r_ui = 3.00   est = 3.39   {'was_impossible': False}
# user: 2          item: 587        r_ui = 3.00   est = 3.54   {'was_impossible': False}
# user: 2          item: 588        r_ui = 3.00   est = 3.86   {'was_impossible': False}
# user: 2          item: 589        r_ui = 5.00   est = 4.04   {'was_impossible': False}
# user: 2          item: 590        r_ui = 5.00   est = 3.83   {'was_impossible': False}
# user: 2          item: 592        r_ui = 5.00   est = 3.54   {'was_impossible': False}
# user: 2          item: 593        r_ui = 3.00   est = 4.25   {'was_impossible': False}
# user: 2          item: 616        r_ui = 3.00   est = 3.67   {'was_impossible': False}
# user: 2          item: 661        r_ui = 4.00   est = 3.75   {'was_impossible': False}
# user: 2          item: 720        r_ui = 4.00   est = 4.22   {'was_impossible': False}

# %%
# Evaluate performance on these predictions
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)
# Out:
# RMSE: 0.9417
# MAE:  0.7352
