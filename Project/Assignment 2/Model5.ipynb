# %% [markdown]
# ## Collaborative Filtering with Cold Start
# ### Model inspried by: Ibtesam Ahmed
# #### Link: https://www.kaggle.com/code/ibtesama/getting-started-with-a-movie-recommendation-system/notebook
#
#
# ##### Using SVD learning model and including user cold start scenario
# ##### Change cold start user to 2
# ##### Gridsearch

# %%
import pandas as pd
from surprise import Reader, Dataset, SVD, accuracy
from surprise.model_selection import GridSearchCV

# %%
# Load dataset
ratings = pd.read_csv('../tmdb/ratings_small.csv')
reader = Reader(rating_scale=(0.5, 5.0))

# %%
# Choose a user to simulate cold start
user_id = 2
user_ratings = ratings[ratings['userId'] == user_id]

# Keep only 5 ratings for the user, remove the rest
keep_ratings = user_ratings.sample(n=5, random_state=42)   # the 5 ratings we keep
remove_ratings = user_ratings.drop(keep_ratings.index)      # the rest we remove

# Remove the other ratings from the dataset for training
train_ratings = ratings.drop(remove_ratings.index)

# %%
# Number of movies user rated
print(len(user_ratings))
# Out:
# 76

# %%
# cold start information
keep_ratings
# Out:
#     userId  movieId  rating  timestamp
# 24       2       50     4.0  835355586
# 55       2      349     4.0  835355441
# 30       2      153     4.0  835355441
# 20       2       10     4.0  835355493
# 65       2      382     3.0  835356165

# %%
# Load the training set into Surprise
train_data = Dataset.load_from_df(train_ratings[['userId','movieId','rating']], reader)
trainset = train_data.build_full_trainset()

# %%
# Grid search for hyperparameter tuning
param_grid = {
    'n_factors': [20, 50, 100],
    'n_epochs': [20, 30],
    'lr_all': [0.002, 0.005],
    'reg_all': [0.02, 0.05]
}

gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3)


gs.fit(trainset)

print("Best RMSE:", gs.best_score['rmse'])
print("Best MAE:", gs.best_score['mae'])
print("Best hyperparameters:", gs.best_params['rmse'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 12
#       2 param_grid = {
#       3     'n_factors': [20, 50, 100],
#       4     'n_epochs': [20, 30],
#       5     'lr_all': [0.002, 0.005],
#       6     'reg_all': [0.02, 0.05]
#       7 }
#       9 gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3)
# ---> 12 gs.fit(trainset)
#      14 print("Best RMSE:", gs.best_score['rmse'])
#      15 print("Best MAE:", gs.best_score['mae'])
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/surprise/model_selection/search.py:100, in BaseSearchCV.fit(self, data)
#      85     raise ValueError(
#      86         "refit cannot be used when data has been "
#      87         "loaded with load_from_folds()."
#      88     )
#      90 cv = get_cv(self.cv)
#      92 delayed_list = (
#      93     delayed(fit_and_score)(
#      94         self.algo_class(**params),
#      95         trainset,
#      96         testset,
#      97         self.measures,
#      98         self.return_train_measures,
#      99     )
# --> 100     for params, (trainset, testset) in product(
#     101         self.param_combinations, cv.split(data)
#     102     )
#     103 )
#     104 out = Parallel(
#     105     n_jobs=self.n_jobs,
#     106     pre_dispatch=self.pre_dispatch,
#     107     verbose=self.joblib_verbose,
#     108 )(delayed_list)
#     110 (test_measures_dicts, train_measures_dicts, fit_times, test_times) = zip(*out)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/surprise/model_selection/split.py:92, in KFold.split(self, data)
#      81 def split(self, data):
#      82     """Generator function to iterate over trainsets and testsets.
#      83
#      84     Args:
#    (...)     89         tuple of (trainset, testset)
#      90     """
# ---> 92     if self.n_splits > len(data.raw_ratings) or self.n_splits < 2:
#      93         raise ValueError(
#      94             "Incorrect value for n_splits={}. "
#      95             "Must be >=2 and less than the number "
#      96             "of ratings".format(len(data.raw_ratings))
#      97         )
#      99     # We use indices to avoid shuffling the original data.raw_ratings list.
#
# AttributeError: 'Trainset' object has no attribute 'raw_ratings'

# %%
# Train the SVD model
best_params = gs.best_params['rmse']
svd = SVD(
    n_factors=best_params['n_factors'],
    n_epochs=best_params['n_epochs'],
    lr_all=best_params['lr_all'],
    reg_all=best_params['reg_all']
)

trainset = trainset.build_full_trainset()
svd.fit(trainset)

# %%
# Predict the removed ratings for the user
predictions = []
for movie_id in remove_ratings['movieId']:
    true_rating = ratings[(ratings['userId'] == user_id) & (ratings['movieId'] == movie_id)]['rating'].values[0]
    pred = svd.predict(user_id, movie_id, r_ui=true_rating)
    predictions.append(pred)
    print(pred)
# Out:
# user: 2          item: 17         r_ui = 5.00   est = 3.92   {'was_impossible': False}
# user: 2          item: 39         r_ui = 5.00   est = 3.55   {'was_impossible': False}
# user: 2          item: 47         r_ui = 4.00   est = 4.18   {'was_impossible': False}
# user: 2          item: 52         r_ui = 3.00   est = 3.65   {'was_impossible': False}
# user: 2          item: 62         r_ui = 3.00   est = 4.06   {'was_impossible': False}
# user: 2          item: 110        r_ui = 4.00   est = 4.31   {'was_impossible': False}
# user: 2          item: 144        r_ui = 3.00   est = 3.65   {'was_impossible': False}
# user: 2          item: 150        r_ui = 5.00   est = 4.01   {'was_impossible': False}
# user: 2          item: 161        r_ui = 3.00   est = 4.04   {'was_impossible': False}
# user: 2          item: 165        r_ui = 3.00   est = 3.61   {'was_impossible': False}
# user: 2          item: 168        r_ui = 3.00   est = 3.53   {'was_impossible': False}
# user: 2          item: 185        r_ui = 3.00   est = 3.42   {'was_impossible': False}
# user: 2          item: 186        r_ui = 3.00   est = 3.14   {'was_impossible': False}
# user: 2          item: 208        r_ui = 3.00   est = 3.17   {'was_impossible': False}
# user: 2          item: 222        r_ui = 5.00   est = 4.06   {'was_impossible': False}
# user: 2          item: 223        r_ui = 1.00   est = 3.93   {'was_impossible': False}
# user: 2          item: 225        r_ui = 3.00   est = 3.64   {'was_impossible': False}
# user: 2          item: 235        r_ui = 3.00   est = 3.72   {'was_impossible': False}
# user: 2          item: 248        r_ui = 3.00   est = 3.16   {'was_impossible': False}
# user: 2          item: 253        r_ui = 4.00   est = 3.59   {'was_impossible': False}
# user: 2          item: 261        r_ui = 4.00   est = 3.92   {'was_impossible': False}
# user: 2          item: 265        r_ui = 5.00   est = 4.09   {'was_impossible': False}
# user: 2          item: 266        r_ui = 5.00   est = 3.73   {'was_impossible': False}
# user: 2          item: 272        r_ui = 3.00   est = 4.14   {'was_impossible': False}
# user: 2          item: 273        r_ui = 4.00   est = 3.36   {'was_impossible': False}
# user: 2          item: 292        r_ui = 3.00   est = 3.71   {'was_impossible': False}
# user: 2          item: 296        r_ui = 4.00   est = 4.28   {'was_impossible': False}
# user: 2          item: 300        r_ui = 3.00   est = 3.65   {'was_impossible': False}
# user: 2          item: 314        r_ui = 4.00   est = 4.18   {'was_impossible': False}
# user: 2          item: 317        r_ui = 2.00   est = 3.33   {'was_impossible': False}
# user: 2          item: 319        r_ui = 1.00   est = 3.94   {'was_impossible': False}
# user: 2          item: 339        r_ui = 3.00   est = 3.63   {'was_impossible': False}
# user: 2          item: 350        r_ui = 4.00   est = 3.60   {'was_impossible': False}
# user: 2          item: 356        r_ui = 3.00   est = 4.24   {'was_impossible': False}
# user: 2          item: 357        r_ui = 3.00   est = 3.79   {'was_impossible': False}
# user: 2          item: 364        r_ui = 3.00   est = 3.93   {'was_impossible': False}
# user: 2          item: 367        r_ui = 3.00   est = 3.46   {'was_impossible': False}
# user: 2          item: 370        r_ui = 2.00   est = 3.56   {'was_impossible': False}
# user: 2          item: 371        r_ui = 3.00   est = 3.51   {'was_impossible': False}
# user: 2          item: 372        r_ui = 3.00   est = 3.23   {'was_impossible': False}
# user: 2          item: 377        r_ui = 3.00   est = 3.87   {'was_impossible': False}
# user: 2          item: 405        r_ui = 2.00   est = 2.91   {'was_impossible': False}
# user: 2          item: 410        r_ui = 3.00   est = 3.38   {'was_impossible': False}
# user: 2          item: 454        r_ui = 4.00   est = 3.79   {'was_impossible': False}
# user: 2          item: 457        r_ui = 3.00   est = 4.11   {'was_impossible': False}
# user: 2          item: 468        r_ui = 4.00   est = 3.54   {'was_impossible': False}
# user: 2          item: 474        r_ui = 2.00   est = 3.93   {'was_impossible': False}
# user: 2          item: 480        r_ui = 4.00   est = 3.94   {'was_impossible': False}
# user: 2          item: 485        r_ui = 3.00   est = 3.36   {'was_impossible': False}
# user: 2          item: 497        r_ui = 3.00   est = 4.31   {'was_impossible': False}
# user: 2          item: 500        r_ui = 4.00   est = 3.69   {'was_impossible': False}
# user: 2          item: 508        r_ui = 4.00   est = 4.00   {'was_impossible': False}
# user: 2          item: 509        r_ui = 4.00   est = 3.76   {'was_impossible': False}
# user: 2          item: 515        r_ui = 4.00   est = 4.03   {'was_impossible': False}
# user: 2          item: 527        r_ui = 4.00   est = 4.36   {'was_impossible': False}
# user: 2          item: 537        r_ui = 4.00   est = 3.49   {'was_impossible': False}
# user: 2          item: 539        r_ui = 3.00   est = 3.79   {'was_impossible': False}
# user: 2          item: 550        r_ui = 3.00   est = 3.19   {'was_impossible': False}
# user: 2          item: 551        r_ui = 5.00   est = 3.72   {'was_impossible': False}
# user: 2          item: 552        r_ui = 3.00   est = 3.64   {'was_impossible': False}
# user: 2          item: 585        r_ui = 5.00   est = 3.17   {'was_impossible': False}
# user: 2          item: 586        r_ui = 3.00   est = 3.64   {'was_impossible': False}
# user: 2          item: 587        r_ui = 3.00   est = 3.69   {'was_impossible': False}
# user: 2          item: 588        r_ui = 3.00   est = 3.89   {'was_impossible': False}
# user: 2          item: 589        r_ui = 5.00   est = 4.14   {'was_impossible': False}
# user: 2          item: 590        r_ui = 5.00   est = 3.90   {'was_impossible': False}
# user: 2          item: 592        r_ui = 5.00   est = 3.62   {'was_impossible': False}
# user: 2          item: 593        r_ui = 3.00   est = 4.19   {'was_impossible': False}
# user: 2          item: 616        r_ui = 3.00   est = 3.66   {'was_impossible': False}
# user: 2          item: 661        r_ui = 4.00   est = 3.68   {'was_impossible': False}
# user: 2          item: 720        r_ui = 4.00   est = 4.07   {'was_impossible': False}

# %%
# Evaluate performance on these predictions
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)
# Out:
# RMSE: 0.9485
# MAE:  0.7538
